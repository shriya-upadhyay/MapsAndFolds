# %% [markdown]
# ##Map Examples

# %%
let nums = [1;2;3;4];;

let incremented = List.map (fun x -> x + 1) nums;;
# Out:
# val nums : int list = [1; 2; 3; 4]
# val incremented : int list = [2; 3; 4; 5]
